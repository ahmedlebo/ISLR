# %% [markdown]
# # Conceptual

# %% [markdown]
# ### Question1:
#
# - Null hupothesis($H_{0}$):$B_{TV}$=$B_{radio}$=$B_{newspaper}$=0
# - Conclusions drawn from p-values:
#   * There is a relation between advertising sales and budget.
#   * The p values for TV and radio are statistically significant but for newspaper it is not significant in presence of     the Tv and radio.
#   * So we can make a Multiple linear regression model with only TV and Radio predictors and drop newspaper.

# %% [markdown]
# ### Question2:
#
# #### KNN clasifier(Qualitative Response):
# - Given :Positive integer K and a test observation $x_0$
# - Output:KNN clasifier first identifies the K closest points in the training data to $x_0$,it then estimates the         conditonal probability for class j as the fraction of points whose response values equal j:Pr(Y=j|X=$x_0$).
#   Finally,KNN applies Bayes  rule and classifies the test obsercation $x_0$ to the class with the largest probability.
#
# #### KNN regression(Quantitative Response):
# - Given :Positive integer K and a test observation $x_0$
# - Output:KNN regressor first identifies the K closest points in the training data to $x_0$,it then estimates f($x_0$) as the average of all training responses of the k-nearest points.

# %% [markdown]
# ### Question3:
#
# a) The equation for the models is:
# ŷ = 50 +20GPA +0.07IQ +35Gender +0.01GPA×IQ −10GPA×Gender
#
# which becomes for the males:
# - ŷ =50+20GPA+0.07IQ+0.01GPA×IQ
#
# and for the females:
# - ŷ =85+10GPA+0.07IQ+0.01GPA×IQ
#
# and we can found that:0.07IQ+0.01GPA×IQ is mutual between the 2 equations so for fixed value of IQ and GPA will provide the same answer for males and females so we can check for the parts in the equations that they are different.
# which is (50+20GPA) for males and (85+10GPA) for females:
# - 50+20GPA=85+10GPA
# - GPA= 3.5
#
# Above GPA=3.5 males will earn more and below it females earn more.
#
# So the right answer is: iii)For a fixed value of IQ and GPA,males earn more on average than females provided that GPA is high enough(higher than 3.5 specifically)

# %% [markdown]
# b)Prediction=137100 dollars
#
# c)False
# - Reason: Because IQ range is higher than the range of other predictors so the coefficients related to it are small to account for smaller ranges of predictors but to test significance we have to check for the p-value for each predictor abd the F-statistic to draw a conclusionabout which coefficient is important in our model.

# %% [markdown]
# ## Question4:
#
# A)Without knowing further information,we couldn't tell which model would have the lowest training RSS because we don't know the information related to the irreducible error term but as the trur relationship is linear,we can assume that the linear model woul have lower RSS than the cubic model.
#
# B)In this case the test RSS depends upon the test data, so we have not enough information to conclude. However, we may assume that polynomial regression will have a higher test RSS as the overfit from training would have more error than the linear regression.
#
# C)In this case we can tell with more confidence that the training RSS is lower for the cubic model.Because as the model flexibility increases the model follows the training points resulting in lower training error.
#
# D)There is not enough information to tell which test RSS would be lower for either regression given the problem statement is defined as not knowing “how far it is from linear”. If it is closer to linear than cubic, the linear regression test RSS could be lower than the cubic regression test RSS. Or, if it is closer to cubic than linear, the cubic regression test RSS could be lower than the linear regression test RSS. It is due to bias-variance tradeoff: it is not clear what level of flexibility will fit data better.

# %% [markdown]
# ### Question5:
#
# $$ \hat{y}_{i} = x_{i} \times \frac{\sum_{i'=1}^{n}\left ( x_{i'} y_{i'} \right )}{\sum_{j=1}^{n} x_{j}^{2}} $$
#
# $$ \hat{y}_{i} = \sum_{i'=1}^{n} \frac{\left ( x_{i'} y_{i'} \right ) \times x_{i}}{\sum_{j=1}^{n} x_{j}^{2}} $$
#
# $$ \hat{y}_{i} = \sum_{i'=1}^{n} \left ( \frac{ x_{i} x_{i'} } { \sum_{j=1}^{n} x_{j}^{2} } \times y_{i'} \right ) $$
#
# $$ a_{i'} = \frac{ x_{i} x_{i'} } { \sum_{j=1}^{n} x_{j}^{2} } $$

# %% [markdown]
# ### Question6:
#
# $$ \hat{y}_{i}=\hat{B_{0}}+\hat{B_{1}}*{x} $$
# $$  when: x = \bar{x} $$
# $$ \hat{B_{0}}=\bar{y}-\hat{B_{1}}* \bar{x} $$
# $$ \hat{y}_{i}=\bar{y}-\hat{B_{1}}* \bar{x}+\hat{B_{1}}*\bar{x}= \bar{y}$$

# %% [markdown]
# ### Question7:
#
# $$ \hat{y}_{i} = \hat{B_{1}} \times x_{i}   $$
#
# $$ \hat{B_{1}}=\frac{\sum_{i=1}^{n}\left ( x_{i}* y_{i} \right )}{\sum_{i=1}^{n} x_{i}^{2}} $$
#
# $$ R^{2}= \frac{TSS-RSS}{TSS} $$
#
# $$=\frac{\sum_{i=1}^{n}\left ( y_{i}^{2} \right )-\sum_{i=1}^{n}\left (( y_{i}-\hat{y}_{i})^{2} \right )}{\sum_{i=1}^{n} y_{i}^{2}} $$
#
# $$=\frac{\sum_{i=1}^{n}\left ( y_{i}^{2} \right )-\sum_{i=1}^{n}\left ( y_{i}^2-2y_{i}*\hat{y}+\hat{y}_{i}^{2} \right )}{\sum_{i=1}^{n} y_{i}^{2}} $$
#
# $$=\frac{2*\sum_{i=1}^{n}\left ( y_{i}*\hat{y} \right )-\sum_{i=1}^{n}\left ( \hat{y}_{i}^{2} \right )}{\sum_{i=1}^{n} y_{i}^{2}} $$
#
# $$=\frac{2*\sum_{i=1}^{n}\left ( y_{i}*\hat{B_{1}} \times x_{i} \right )-\sum_{i=1}^{n}\left ( (\hat{B_{1}} \times x_{i})^{2} \right )}{\sum_{i=1}^{n} y_{i}^{2}} $$
#
# $$=\frac{2*\sum_{i=1}^{n}\left ( y_{i}*(\frac{\sum_{i=1}^{n}\left ( x_{i}* y_{i} \right )}{\sum_{i=1}^{n} x_{i}^{2}} \times x_{i} \right ))-\sum_{i=1}^{n}\left ( (\frac{\sum_{i=1}^{n}\left ( x_{i}* y_{i} \right )}{\sum_{i=1}^{n} x_{i}^{2}}) \times x_{i})^{2} \right )}{\sum_{i=1}^{n} y_{i}^{2}} $$
#
# $$=\frac{2*\sum_{i=1}^{n}\left ( x_{i}* y_{i} \right )*(\frac{\sum_{i=1}^{n}\left ( x_{i}* y_{i} \right )}{\sum_{i=1}^{n} x_{i}^{2}})-(\sum_{i=1}^{n}\left ( x_{i}* y_{i} \right ))^2*(\frac{\sum_{i=1}^{n}\left ( x_{i}^2 \right )}{(\sum_{i=1}^{n} x_{i}^{2})^2})}{\sum_{i=1}^{n} y_{i}^{2}}$$
#
# $$=\frac{(\sum_{i=1}^{n}\left ( x_{i}* y_{i} \right ))^2}{\sum_{i=1}^{n} y_{i}^{2} \times \sum_{i=1}^{n} x_{i}^{2} }$$
#
# $$=(Cor(X,Y))^2$$

# %% [markdown]
# ### Question8:

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.gofplots import ProbPlot

# %matplotlib inline

Auto = pd.read_csv('csv/Auto.csv')
Auto['intercept']=1
#Auto.head()
mod=sm.OLS(Auto['mpg'],Auto[['intercept','horsepower']])
results=mod.fit()
print(results.summary())
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /anaconda3/envs/tf/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           7.03e-81
# Time:                        07:48:04   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# ...

# %% [markdown]
# ####  i) Testing the hypothesis $H_{0}$:$B_{1}$=0 ∀i. The p-value corresponding to the F-statistic is $7.03*10^{-81}$, this indicates a clear evidence of a relationship between “mpg” and “horsepower”.
# #### ii) p-value for horsepower as a predictor is close to 0 which means that the relationship is strong and also The model with horsepower as a predictor predicts 60.6% of the variance in the mpg (response)
# #### iii) The relationship is negative.
# #### iv) mpg=24.467

# %%
X=[1,98]
predictions = results.get_prediction(X).summary_frame(alpha = 0.05)
y_prd = np.float(predictions['mean'])
#print(predictions.summary_frame(alpha = 0.05))
yprd_pred_lower = np.float(predictions['obs_ci_lower'])
yprd_pred_upper = np.float(predictions['obs_ci_upper'])
yprd_ci_upper = np.float(predictions['mean_ci_upper'])
yprd_ci_lower = np.float(predictions['mean_ci_lower'])
print("Based on confidence intervals:")
print("Mean={}, Upper={}, Lower={}".format(y_prd,yprd_ci_upper,yprd_ci_lower))

print("Based on Preduction intervals:")
print("Mean={}, Upper={}, Lower={}".format(y_prd,yprd_pred_upper,yprd_pred_lower))
# Out:
# Based on confidence intervals:
# Mean=24.46707715251243, Upper=24.961075344320918, Lower=23.973078960703944
# Based on Preduction intervals:
# Mean=24.46707715251243, Upper=34.12475823405774, Lower=14.809396070967123

# %%
#b)
x = Auto[['horsepower']]
y=Auto[['mpg']]
fig, ax = plt.subplots(figsize=(10,7))
ax.plot(x, results.fittedvalues, 'r-', label="OLS")
ax.plot(x, y, 'bo', label="data")
#fig = sm.graphics.plot_fit(results, 1, ax=ax,vlines=False)
ax.set_ylabel("mpg")
ax.set_xlabel("horsepower")
ax.set_title("Linear Regression")

plt.show()

# %%
#c)
# fitted values (need a constant term for intercept)
model_fitted_y = results.fittedvalues

# model residuals
model_residuals = results.resid

# normalized residuals
model_norm_residuals = results.get_influence().resid_studentized_internal

# absolute normalized residuals
model_norm_residuals_abs = (np.abs(model_norm_residuals))
# absolute squared normalized residuals
model_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))

# absolute residuals
model_abs_resid = np.abs(model_residuals)

# leverage, from statsmodels internals
model_leverage = results.get_influence().hat_matrix_diag

# cook's distance, from statsmodels internals
model_cooks = results.get_influence().cooks_distance[0]

# %%
plot_lm_1 = plt.figure(1)
plot_lm_1.set_figheight(8)
plot_lm_1.set_figwidth(12)

plot_lm_1.axes[0] = sns.residplot(model_fitted_y, 'mpg', data=Auto,
                                  lowess=True,
                                  scatter_kws={'alpha': 0.5},
                                  line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_1.axes[0].set_title('Residuals vs Fitted')
plot_lm_1.axes[0].set_xlabel('Fitted values')
plot_lm_1.axes[0].set_ylabel('Residuals')


# annotations
abs_resid = model_abs_resid.sort_values(ascending=False)
abs_resid_top_3 = abs_resid[:3]

for i in abs_resid_top_3.index:
    plot_lm_1.axes[0].annotate(i, 
                               xy=(model_fitted_y[i], 
                                   model_residuals[i]));

# %% [markdown]
# #### As we can see the red line is a smooth fit to the residuals which exhibit a clear U-shape which provides a strong indication of non-linearity in the data.

# %%
'''Q Q Plots (Quantile-Quantile plots) are plots of two quantiles against each other. 
A quantile is a fraction where certain values fall below that quantile. 
For example, the median is a quantile where 50% of the data fall below that point and 50% lie above it. 
The purpose of Q Q plots is to find out if two sets of data come from the same distribution. 
A 45 degree angle is plotted on the Q Q plot; 
if the two data sets come from a common distribution, the points will fall on that reference line.'''
QQ = ProbPlot(model_norm_residuals)
plot_lm_2 = QQ.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1)

plot_lm_2.set_figheight(8)
plot_lm_2.set_figwidth(12)

plot_lm_2.axes[0].set_title('Normal Q-Q')
plot_lm_2.axes[0].set_xlabel('Theoretical Quantiles')
plot_lm_2.axes[0].set_ylabel('Standardized Residuals');

# annotations
abs_norm_resid = np.flip(np.argsort(np.abs(model_norm_residuals)), 0)
abs_norm_resid_top_3 = abs_norm_resid[:3]

for r, i in enumerate(abs_norm_resid_top_3):
    plot_lm_2.axes[0].annotate(i, 
                               xy=(np.flip(QQ.theoretical_quantiles, 0)[r],
                                   model_norm_residuals[i]));

# %%
plot_lm_3 = plt.figure(3)
plot_lm_3.set_figheight(8)
plot_lm_3.set_figwidth(12)

plt.scatter(model_fitted_y, model_norm_residuals_abs, alpha=0.5)
sns.regplot(model_fitted_y, model_norm_residuals_abs, 
            scatter=False, 
            ci=False, 
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_3.axes[0].set_title('Scale-Location')
plot_lm_3.axes[0].set_xlabel('Fitted values')
plot_lm_3.axes[0].set_ylabel('|Standardized Residuals|');

# annotations
abs_sq_norm_resid = np.flip(np.argsort(model_norm_residuals_abs), 0)
abs_sq_norm_resid_top_3 = abs_sq_norm_resid[:3]

for i in abs_norm_resid_top_3:
    plot_lm_3.axes[0].annotate(i, 
                               xy=(model_fitted_y[i], 
                                   model_norm_residuals_abs[i]));

# %% [markdown]
# #### As we can see here there is some points close and above 3 in the standardized residuals and we consider them as outliers.

# %%
'''Cook’s distance, Di, is used in Regression Analysis to find influential outliers in a set of predictor variables.
In other words, it’s a way to identify points that negatively affect your regression model.
The measurement is a combination of each observation’s leverage and residual values; 
the higher the leverage and residuals, the higher the Cook’s distance.'''
plot_lm_4 = plt.figure(4)
plot_lm_4.set_figheight(8)
plot_lm_4.set_figwidth(12)

plt.scatter(model_leverage, model_norm_residuals, alpha=0.5)
sns.regplot(model_leverage, model_norm_residuals, 
            scatter=False, 
            ci=False, 
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_lm_4.axes[0].set_xlim(0, 0.040)
plot_lm_4.axes[0].set_ylim(-3, 5)
plot_lm_4.axes[0].set_title('Residuals vs Leverage')
plot_lm_4.axes[0].set_xlabel('Leverage')
plot_lm_4.axes[0].set_ylabel('Standardized Residuals')

# annotations
leverage_top_3 = np.flip(np.argsort(model_cooks), 0)[:3]

for i in leverage_top_3:
    plot_lm_4.axes[0].annotate(i, 
                               xy=(model_leverage[i], 
                                   model_norm_residuals[i]))
    
# shenanigans for cook's distance contours
def graph(formula, x_range, label=None):
    x = x_range
    y = formula(x)
    plt.plot(x, y, label=label, lw=1, ls='--', color='red')

p = len(results.params) # number of model parameters

graph(lambda x: np.sqrt((0.5 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50), 
      'Cook\'s distance') # 0.5 line

graph(lambda x: np.sqrt((1 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50)) # 1 line

plt.legend(loc='upper right');

# %% [markdown]
# #### Most of the points fall between 0 and 0.015 so we can see that there is some high leverage points but fortunately the outliers are not the same points as the high-leverage points.

# %% [markdown]
# ## Question9:

# %%
Auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name  intercept
# 0       1  chevrolet chevelle malibu          1
# 1       1          buick skylark 320          1
# 2       1         plymouth satellite          1
# 3       1              amc rebel sst          1
# 4       1                ford torino          1

# %%
#A)
sns.pairplot(data=Auto.drop('intercept',axis=1))

# %%
#B)
Auto.drop('intercept',axis=1).corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# ...

# %%
plt.figure(figsize=[10,8])
sns.heatmap(Auto.drop('intercept',axis=1).corr(),annot=True,cmap='viridis_r')

# %%
#C)
model=sm.OLS(Auto['mpg'],Auto.drop(['mpg','name'],axis=1))
multiple_model=model.fit()
print(multiple_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     252.4
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):          2.04e-139
# Time:                        07:48:50   Log-Likelihood:                -1023.5
# No. Observations:                 392   AIC:                             2063.
# Df Residuals:                     384   BIC:                             2095.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# cylinders       -0.4934      0.323     -1.526      0.128      -1.129       0.142
# ...

# %% [markdown]
# ####  i) Testing the hypothesis $H_{0}$:$B_{i}$=0 ∀i. The p-value corresponding to the F-statistic is $2.04*10^{-139}$, this indicates a clear evidence of a relationship between predictors and response(mpg).
# #### ii) p-value for all predictors is statistically significant except for ['Cylinders','acceleration','horsepower']
# #### iii) The relationship is positive between mpg and year that suggests that the average effect of an increase of 1 year is an increase of 0.7507727 in “mpg” (all other predictors remaining constant). In other words, cars become more fuel efficient every year by almost 1 mpg / year.

# %%
#d)

multiple_model_fitted_y = multiple_model.fittedvalues
multiple_model_residuals = multiple_model.resid
multiple_model_norm_residuals = multiple_model.get_influence().resid_studentized_internal
multiple_model_norm_residuals_abs = (np.abs(model_norm_residuals))
multiple_model_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))
multiple_model_abs_resid = np.abs(model_residuals)
multiple_model_leverage = multiple_model.get_influence().hat_matrix_diag
multiple_model_cooks = multiple_model.get_influence().cooks_distance[0]

# %%
plot_mlm_1 = plt.figure(1)
plot_mlm_1.set_figheight(8)
plot_mlm_1.set_figwidth(12)

plot_mlm_1.axes[0] = sns.residplot(multiple_model_fitted_y, 'mpg', data=Auto,
                                  lowess=True,
                                  scatter_kws={'alpha': 0.5},
                                  line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_mlm_1.axes[0].set_title('Residuals vs Fitted')
plot_mlm_1.axes[0].set_xlabel('Fitted values')
plot_mlm_1.axes[0].set_ylabel('Residuals')


# annotations
abs_resid = multiple_model_abs_resid.sort_values(ascending=False)
abs_resid_top_3 = abs_resid[:3]

for i in abs_resid_top_3.index:
    plot_mlm_1.axes[0].annotate(i, 
                               xy=(multiple_model_fitted_y[i], 
                                   multiple_model_residuals[i]));

# %% [markdown]
# #### As we can see the red line is a smooth fit to the residuals which exhibit a clear U-shape which provides a strong indication of non-linearity in the data like the simple model.

# %%
QQm = ProbPlot(multiple_model_norm_residuals)
plot_mlm_2 = QQm.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1)

plot_mlm_2.set_figheight(8)
plot_mlm_2.set_figwidth(12)

plot_mlm_2.axes[0].set_title('Normal Q-Q')
plot_mlm_2.axes[0].set_xlabel('Theoretical Quantiles')
plot_mlm_2.axes[0].set_ylabel('Standardized Residuals');

# annotations
abs_norm_resid = np.flip(np.argsort(np.abs(multiple_model_norm_residuals)), 0)
abs_norm_resid_top_3 = abs_norm_resid[:3]

for r, i in enumerate(abs_norm_resid_top_3):
    plot_mlm_2.axes[0].annotate(i, 
                               xy=(np.flip(QQ.theoretical_quantiles, 0)[r],
                                   multiple_model_norm_residuals[i]));

# %%
plot_mlm_3 = plt.figure(3)
plot_mlm_3.set_figheight(8)
plot_mlm_3.set_figwidth(12)

plt.scatter(multiple_model_fitted_y, multiple_model_norm_residuals_abs, alpha=0.5)
sns.regplot(multiple_model_fitted_y, multiple_model_norm_residuals_abs, 
            scatter=False, 
            ci=False, 
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_mlm_3.axes[0].set_title('Scale-Location')
plot_mlm_3.axes[0].set_xlabel('Fitted values')
plot_mlm_3.axes[0].set_ylabel('|Standardized Residuals|');

# annotations
abs_sq_norm_resid = np.flip(np.argsort(model_norm_residuals_abs), 0)
abs_sq_norm_resid_top_3 = abs_sq_norm_resid[:3]

for i in abs_norm_resid_top_3:
    plot_mlm_3.axes[0].annotate(i, 
                               xy=(multiple_model_fitted_y[i], 
                                   multiple_model_norm_residuals_abs[i]));

# %%
plot_mlm_4 = plt.figure(4)
plot_mlm_4.set_figheight(8)
plot_mlm_4.set_figwidth(12)

plt.scatter(multiple_model_leverage, multiple_model_norm_residuals, alpha=0.5)
sns.regplot(multiple_model_leverage, multiple_model_norm_residuals, 
            scatter=False, 
            ci=False, 
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_mlm_4.axes[0].set_xlim(0, 0.20)
plot_mlm_4.axes[0].set_ylim(-3, 5)
plot_mlm_4.axes[0].set_title('Residuals vs Leverage')
plot_mlm_4.axes[0].set_xlabel('Leverage')
plot_mlm_4.axes[0].set_ylabel('Standardized Residuals')

# annotations
leverage_top_3 = np.flip(np.argsort(multiple_model_cooks), 0)[:3]

for i in leverage_top_3:
    plot_mlm_4.axes[0].annotate(i, 
                               xy=(model_leverage[i], 
                                   model_norm_residuals[i]))
    
# shenanigans for cook's distance contours
def graph(formula, x_range, label=None):
    x = x_range
    y = formula(x)
    plt.plot(x, y, label=label, lw=1, ls='--', color='red')

p = len(multiple_model.params) # number of model parameters

graph(lambda x: np.sqrt((0.5 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50), 
      'Cook\'s distance') # 0.5 line

graph(lambda x: np.sqrt((1 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50)) # 1 line

plt.legend(loc='upper right');

# %% [markdown]
# #### The plot of standardized residuals versus leverage indicates the presence of a few outliers (higher than 2 or lower than -2) and 2 high leverage points.

# %%
#E)
multiple_with_interaction = smf.ols(formula='mpg ~ weight * displacement+ weight*year', data=Auto).fit()
print(multiple_with_interaction.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     466.2
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):          4.42e-161
# Time:                        07:48:54   Log-Likelihood:                -978.72
# No. Observations:                 392   AIC:                             1969.
# Df Residuals:                     386   BIC:                             1993.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             -60.1663     13.725     -4.384      0.000     -87.151     -33.182
# ...

# %% [markdown]
# ##### From the p-values we can find that the interaction between (weight/displacement) and (weight/year) are statistically significant and the whole model is able to predict approximately 86% of the variance in the model

# %%
fig, axs = plt.subplots(1, 3,figsize=(16, 8))
x=np.array(Auto['displacement'])
y=np.array(Auto['mpg'])
axs[0].scatter(x=Auto['displacement'], y=Auto['mpg'],color='red')
axs[0].set_title('Dispacement vs mpg')
axs[0].set(xlabel='Dispalcement')
axs[1].scatter(x=np.log10(Auto['displacement']),y=Auto['mpg'])
axs[1].set_title('$\log{(Dispacement)}$ vs mpg')
axs[1].set(xlabel='$\log{(Dispacement)}$')
axs[2].scatter(np.sqrt(Auto['displacement']), y=Auto['mpg'], color='green')
axs[2].set_title('$\sqrt{Dispacement}$ vs mpg')
axs[2].set(xlabel='$\sqrt{Dispacement}$')
for ax in axs.flat:
    ax.set( ylabel='mpg')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# #### It seems like data points follow the same curve in all plots but we can say that approximately the log transformation make it more linear.

# %% [markdown]
# ## Question10:

# %%
Carseats=pd.read_csv('csv/Carseats.csv')
Carseats.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
Carseats['Urban']=Carseats['Urban'].apply(lambda x:1 if x=='Yes' else 0)
Carseats['US']=Carseats['US'].apply(lambda x:1 if x=='Yes' else 0)

# %%
Carseats['intercept']=1
Carseats.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education  Urban  US  intercept
# 0         17      1   1          1
# 1         10      1   1          1
# 2         12      1   1          1
# 3         14      1   1          1
# 4         13      1   0          1

# %%
#A)
model_1=sm.OLS(Carseats['Sales'],Carseats[['intercept','Price','US','Urban']]).fit()
print(model_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     41.52
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           2.39e-23
# Time:                        07:48:57   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1863.
# Df Residuals:                     396   BIC:                             1879.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     13.0435      0.651     20.036      0.000      11.764      14.323
# ...

# %% [markdown]
# #### B) The coefficient of the “Price” variable may be interpreted by saying that the average effect of a price increase of 1 dollar is a decrease of 54.4588492 units in sales with all other predictors remaining fixed. And its  p-value shows that it is significant for the model.
# #### The coefficient of the “US” variable may be interpreted by saying that on average the unit sales in a US store are 1200.6 units more than in a non US store all other predictors remaining fixed.And its  p-value shows that it is significant for the model.
# #### The coefficient of the “Urban” variable may be interpreted by saying that on average the unit sales in urban location are 21.9 units less than in rural location all other predictors remaining fixed. And its  p-value shows that it is not significant for the model.

# %% [markdown]
# #### C)The model may be written as
# $$ Sales=13.0434689+(−0.0545)×Price+(-0.0219)×Urban+(1.2006)×US+ε $$

# %% [markdown]
# #### D) We can reject the null hypothesis for ['Sales','US']

# %%
#E)
model_2=sm.OLS(Carseats['Sales'],Carseats[['intercept','Price','US']]).fit()
print(model_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     62.43
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           2.66e-24
# Time:                        07:48:57   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1861.
# Df Residuals:                     397   BIC:                             1873.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     13.0308      0.631     20.652      0.000      11.790      14.271
# ...

# %% [markdown]
# #### The model in e is slightly better in $R^{2}$ and F-statistic but only 24% of the variability is explained by the best of the 2 models which suggests that our relationship is far from linear.

# %%
#g)
model_2.conf_int()
# Out:
#                   0          1
# intercept  11.79032  14.271265
# Price      -0.06476  -0.044195
# US          0.69152   1.707766

# %%
#h)
model_2_fitted_y = model_2.fittedvalues
model_2_residuals = model_2.resid
model_2_norm_residuals = model_2.get_influence().resid_studentized_internal
model_2_norm_residuals_abs = (np.abs(model_norm_residuals))
model_2_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))
model_2_abs_resid = np.abs(model_residuals)
model_2_leverage = model_2.get_influence().hat_matrix_diag
model_2_cooks = model_2.get_influence().cooks_distance[0]

# %%
plot_m_2 = plt.figure(4)
plot_m_2.set_figheight(8)
plot_m_2.set_figwidth(12)

plt.scatter(model_2_leverage, model_2_norm_residuals, alpha=0.5)
sns.regplot(model_2_leverage, model_2_norm_residuals, 
            scatter=False, 
            ci=False, 
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

plot_m_2.axes[0].set_xlim(0, 0.05)
plot_m_2.axes[0].set_ylim(-3, 5)
plot_m_2.axes[0].set_title('Residuals vs Leverage')
plot_m_2.axes[0].set_xlabel('Leverage')
plot_m_2.axes[0].set_ylabel('Standardized Residuals')

# annotations
leverage_top_3 = np.flip(np.argsort(multiple_model_cooks), 0)[:3]

for i in leverage_top_3:
    plot_m_2.axes[0].annotate(i, 
                               xy=(model_leverage[i], 
                                   model_norm_residuals[i]))
    
# shenanigans for cook's distance contours
def graph(formula, x_range, label=None):
    x = x_range
    y = formula(x)
    plt.plot(x, y, label=label, lw=1, ls='--', color='red')

p = len(multiple_model.params) # number of model parameters

graph(lambda x: np.sqrt((0.5 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50), 
      'Cook\'s distance') # 0.5 line

graph(lambda x: np.sqrt((1 * p * (1 - x)) / x), 
      np.linspace(0.001, 0.200, 50)) # 1 line

plt.legend(loc='upper right');

# %% [markdown]
# #### The plot of standardized residuals versus leverage indicates the presence of a few outliers (higher than 2 or lower than -2) and some leverage points as some points exceed 3*(p+1)/n .

# %% [markdown]
# ## Question 11:

# %%
n = 100
df=pd.DataFrame()
np.random.seed(1)
df['X'] = np.random.randn(n)
df['Y'] = 2*df['X']+ np.random.randn(n)

# %%
model_1=sm.OLS(df['Y'],df['X']).fit()
print(model_1.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared (uncentered):                   0.798
# Model:                            OLS   Adj. R-squared (uncentered):              0.796
# Method:                 Least Squares   F-statistic:                              391.7
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):                    3.46e-36
# Time:                        07:48:58   Log-Likelihood:                         -135.67
# No. Observations:                 100   AIC:                                      273.3
# Df Residuals:                      99   BIC:                                      275.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ##### A)Coefficient=2.1067
# ##### Std. error=0.106
# ##### t-statistic=19.792
# ##### p-value=0
# ##### The small p-value allows us to reject null hypothesis $H_0$

# %%
model_2=sm.OLS(df['X'],df['Y']).fit()
print(model_2.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      X   R-squared (uncentered):                   0.798
# Model:                            OLS   Adj. R-squared (uncentered):              0.796
# Method:                 Least Squares   F-statistic:                              391.7
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):                    3.46e-36
# Time:                        07:48:58   Log-Likelihood:                         -49.891
# No. Observations:                 100   AIC:                                      101.8
# Df Residuals:                      99   BIC:                                      104.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ##### B)Coefficient=0.3789
# ##### Std. error=0.019
# ##### t-statistic=19.792
# ##### p-value=0
# ##### The small p-value allows us to reject null hypothesis $H_0$

# %% [markdown]
# ##### C)We obtain the same value for the t-statistic and consequently the same value for the corresponding p-value. Both results in (a) and (b) reflect the same line created in (a). In other words, y=2x+ε could also be written x=0.5(y−ε).

# %% [markdown]
# #### D)
# $$ {t} =  \frac{\hat {B}}{SE(\hat {B})} $$
#
# $$ =\frac{\frac{\sum_{i=1}^{n}\left ( x_{i} y_{i} \right )}{\sum_{j=1}^{n} x_{j}^{2}}}{\sqrt {\frac{{\sum_{i'=1}^{n}\left (  y_{i'}-x_{i'}*\hat {B} \right )^2)}}{(n-1) \times \sum_{j'=1}^{n} x_{j}^{2}}} } $$
#
# $$ =\frac{\sqrt{(n-1)} \times \sum_{i=1}^{n}\left ( x_{i} y_{i} \right )}{\sqrt{\sum_{j=1}^{n} x_{j}^{2} \times \sum_{i'=1}^{n}\left (  y_{i'}-x_{i'}*\hat {B} \right )^2)}}  $$
#
# $$ \sum_{j=1}^{n} x_{j}^{2} \times \sum_{i'=1}^{n}\left (  y_{i'}-x_{i'}*\hat {B} \right )^2)=\sum_{j=1}^{n} x_{j}^{2} \times \sum_{i'=1}^{n}\left (  y_{i'}^2-2y_{i'}*x_{i'}*\hat {B}+(x_{i'}*\hat {B})^2 \right )) $$
# $$ =\sum_{j=1}^{n} x_{j}^{2} \times \sum_{i'=1}^{n}\left (  y_{i'}^2-2y_{i'}*x_{i'}*\frac{\sum_{i'=1}^{n}\left ( x_{i'} y_{i'} \right )}{\sum_{j=1}^{n} x_{j}^{2}}+(x_{i'})^2*(\frac{\sum_{i'=1}^{n}\left ( x_{i'} y_{i'} \right )}{\sum_{j=1}^{n} x_{j}^{2}})^2 \right )) $$
# $$=\sum_{j=1}^{n} x_{j}^{2} \times \sum_{j=1}^{n} y_{j}^{2} - \sum_{i=1}^{n}\left ( x_{i} y_{i} \right )^2 $$
#
# $$ {t} =  \frac{\sqrt{(n-1)} \times \sum_{i=1}^{n}\left ( x_{i} y_{i} \right )}{\sqrt{\sum_{j=1}^{n} x_{j}^{2} \times \sum_{j=1}^{n} y_{j}^{2} - (\sum_{i=1}^{n}\left ( x_{i} y_{i} \right ))^2}} $$

# %%
#E)
n=len(df['X'])
sum_1=np.sum(df['X']*df["Y"])
sum_2=sum_1**2
x_sum=np.sum(df['X']**2)
y_sum=np.sum(df['Y']**2)
t=(np.sqrt(n-1)*sum_1)/(np.sqrt((x_sum*y_sum)-sum_2))

# %%
t
# Out:
# 19.791801987091205

# %%
#F)
model_3=smf.ols(formula='Y~X',data=df).fit()
print(model_3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     391.4
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           5.39e-36
# Time:                        07:48:58   Log-Likelihood:                -134.44
# No. Observations:                 100   AIC:                             272.9
# Df Residuals:                      98   BIC:                             278.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1470      0.094      1.564      0.121      -0.039       0.334
# ...

# %%
model_4=smf.ols(formula='X~Y',data=df).fit()
print(model_4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      X   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     391.4
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           5.39e-36
# Time:                        07:48:58   Log-Likelihood:                -49.289
# No. Observations:                 100   AIC:                             102.6
# Df Residuals:                      98   BIC:                             107.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0440      0.040     -1.090      0.279      -0.124       0.036
# ...

# %% [markdown]
# ##### It is again easy to see that the t-statistic for “model_3” and “model_4” are both equal to 19.783.

# %% [markdown]
# ## Question12:

# %% [markdown]
#  #### A) The coefficient estimate of X onto Y :
#  $$ \hat{B}= \frac{\sum_{i'=1}^{n}\left ( x_{i'} y_{i'} \right )}{\sum_{j=1}^{n} x_{j}^{2}} $$
#  #### The coefficient estimate of Y onto X :
#  $$ \hat{B}= \frac{\sum_{i'=1}^{n}\left ( x_{i'} y_{i'} \right )}{\sum_{j=1}^{n} y_{j}^{2}} $$
#  #### In order to have the same coefficient for both we must have:
#  $$ \sum_{j=1}^{n} y_{j}^{2}= \sum_{j=1}^{n} x_{j}^{2} $$

# %%
#B)
n = 100
df_2=pd.DataFrame()
np.random.seed(1)
df_2['X'] = np.random.randn(n)
df_2['Y'] = 3*df_2['X']+ np.random.randn(n)
print(sum(df_2['X']**2))
print(sum(df_2['Y']**2))
# Out:
# 78.71718048502926
# 848.0651115187903

# %%
model_1=smf.ols(formula="Y~X+0",data=df_2).fit()
print(model_1.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared (uncentered):                   0.896
# Model:                            OLS   Adj. R-squared (uncentered):              0.895
# Method:                 Least Squares   F-statistic:                              851.8
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):                    1.97e-50
# Time:                        07:48:58   Log-Likelihood:                         -135.67
# No. Observations:                 100   AIC:                                      273.3
# Df Residuals:                      99   BIC:                                      275.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model_2=smf.ols(formula="X~Y+0",data=df_2).fit()
print(model_2.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      X   R-squared (uncentered):                   0.896
# Model:                            OLS   Adj. R-squared (uncentered):              0.895
# Method:                 Least Squares   F-statistic:                              851.8
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):                    1.97e-50
# Time:                        07:48:59   Log-Likelihood:                         -16.817
# No. Observations:                 100   AIC:                                      35.63
# Df Residuals:                      99   BIC:                                      38.24
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#C)
n = 100
df_3=pd.DataFrame()
np.random.seed(1)
df_3['X'] = np.random.randn(n)
df_3['Y'] = df_3['X']
print(sum(df_3['X']**2))
print(sum(df_3['Y']**2))
# Out:
# 78.71718048502926
# 78.71718048502926

# %%
model_3=smf.ols(formula="Y~X+0",data=df_3).fit()
print(model_3.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          2.049e+33
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        07:48:59   Log-Likelihood:                          3475.4
# No. Observations:                 100   AIC:                                     -6949.
# Df Residuals:                      99   BIC:                                     -6946.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model_4=smf.ols(formula="Y~X+0",data=df_3).fit()
print(model_4.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          2.049e+33
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        07:48:59   Log-Likelihood:                          3475.4
# No. Observations:                 100   AIC:                                     -6949.
# Df Residuals:                      99   BIC:                                     -6946.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Question13:

# %%
#a&b)
x = np.random.normal(0, 1, 100)
eps=np.random.normal(0, 0.25, 100)

# %%
y=-1+0.5*x+eps

# %%
#c)
len(y)
# Out:
# 100

# %%
X=sm.add_constant(x)
linear_model=sm.OLS(y,X).fit()
print(linear_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     429.6
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           1.34e-37
# Time:                        07:48:59   Log-Likelihood:                -1.7658
# No. Observations:                 100   AIC:                             7.532
# Df Residuals:                      98   BIC:                             12.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.0057      0.025    -39.892      0.000      -1.056      -0.956
# ...

# %% [markdown]
# ##### $B_{0}$=-1.0057.
# ##### $B_{1}$=0.5533

# %%
#D&E)
plt.figure(figsize=[12,10])
plt.scatter(x=x,y=y)
plt.title("Y vs X")
plt.xlabel("X")
plt.ylabel("Y")
sns.regplot(x=x,y=y);

# %%
#F)
plt.figure(figsize=[12,10])
plt.scatter(x=x,y=y)
plt.title("Y vs X")
plt.xlabel("X")
plt.ylabel("Y")
sns.regplot(x=x,y=y)
plt.plot(x, 0.5533*x-1.0057, '-b', label='y=0.53x-1.0')
plt.plot(x, 0.5*x-1, '-r', label='y=0.5x-1')
plt.legend(loc='upper left');

# %%
#G)
x_2=x**2

# %%
df_3=pd.DataFrame()
df_3['x']=x
df_3['x_2']=x**2
df_3['y']=y
linear_model_sq=smf.ols(formula="y~x+x_2" ,data=df_3).fit()
print(linear_model_sq.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     212.6
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           3.49e-36
# Time:                        07:49:03   Log-Likelihood:                -1.7657
# No. Observations:                 100   AIC:                             9.531
# Df Residuals:                      97   BIC:                             17.35
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0054      0.031    -32.941      0.000      -1.066      -0.945
# ...

# %% [markdown]
# #### The coefficient for “x^2” is not significant as its p-value is higher than 0.05. So there is not sufficient evidence that the quadratic term improves the model fit even though the R2 is the same as the linear model with x only.

# %% [markdown]
# #### Reeat with less noise and higher noise the same process
# ### You will find we reduced the noise by decreasing the variance of the normal distribution used to generate the error term ε. We may see that the coefficients are very close to the previous ones, but now, as the relationship is nearly linear, we will have a much higher R2 and much lower RSE. Moreover, the two lines overlap each other as we have very little noise.
#
# ### You will find we reduced the noise by increasing the variance of the normal distribution used to generate the error term ε. We may see that the coefficients are very close to the previous ones, but now, as the relationship is nearly linear, we will have a much lower R2 and much lower RSE. Moreover, the two lines will be separeted from each other as we have very high noise.

# %% [markdown]
# ## Question15:

# %%
Boston=pd.read_csv('csv/Boston.csv')

colums=list(Boston.columns)
print(colums)
Boston.head()
# Out:
# ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv']
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
model_zn=smf.ols(formula="crim~zn",data=Boston).fit()
print(model_zn.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     21.10
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           5.51e-06
# Time:                        07:49:03   Log-Likelihood:                -1796.0
# No. Observations:                 506   AIC:                             3596.
# Df Residuals:                     504   BIC:                             3604.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.4537      0.417     10.675      0.000       3.634       5.273
# ...

# %%
model_indus=smf.ols(formula="crim~indus",data=Boston).fit()
print(model_indus.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     99.82
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           1.45e-21
# Time:                        07:49:03   Log-Likelihood:                -1760.6
# No. Observations:                 506   AIC:                             3525.
# Df Residuals:                     504   BIC:                             3534.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.0637      0.667     -3.093      0.002      -3.375      -0.753
# ...

# %%
model_chas=smf.ols(formula="crim~chas",data=Boston).fit()
print(model_chas.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.579
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):              0.209
# Time:                        07:49:03   Log-Likelihood:                -1805.6
# No. Observations:                 506   AIC:                             3615.
# Df Residuals:                     504   BIC:                             3624.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.7444      0.396      9.453      0.000       2.966       4.523
# ...

# %%
model_nox=smf.ols(formula="crim~nox",data=Boston).fit()
print(model_nox.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.176
# Method:                 Least Squares   F-statistic:                     108.6
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           3.75e-23
# Time:                        07:49:03   Log-Likelihood:                -1757.0
# No. Observations:                 506   AIC:                             3518.
# Df Residuals:                     504   BIC:                             3526.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -13.7199      1.699     -8.073      0.000     -17.059     -10.381
# ...

# %%
model_rm=smf.ols(formula="crim~rm",data=Boston).fit()
print(model_rm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     25.45
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           6.35e-07
# Time:                        07:49:03   Log-Likelihood:                -1793.9
# No. Observations:                 506   AIC:                             3592.
# Df Residuals:                     504   BIC:                             3600.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     20.4818      3.364      6.088      0.000      13.872      27.092
# ...

# %%
model_age=smf.ols(formula="crim~age",data=Boston).fit()
print(model_age.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     71.62
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           2.85e-16
# Time:                        07:49:03   Log-Likelihood:                -1772.7
# No. Observations:                 506   AIC:                             3549.
# Df Residuals:                     504   BIC:                             3558.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.7779      0.944     -4.002      0.000      -5.633      -1.923
# ...

# %%
model_dis=smf.ols(formula="crim~dis",data=Boston).fit()
print(model_dis.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     84.89
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           8.52e-19
# Time:                        07:49:04   Log-Likelihood:                -1767.0
# No. Observations:                 506   AIC:                             3538.
# Df Residuals:                     504   BIC:                             3546.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.4993      0.730     13.006      0.000       8.064      10.934
# ...

# %%
model_rad=smf.ols(formula="crim~rad",data=Boston).fit()
print(model_rad.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     323.9
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           2.69e-56
# Time:                        07:49:04   Log-Likelihood:                -1680.8
# No. Observations:                 506   AIC:                             3366.
# Df Residuals:                     504   BIC:                             3374.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.2872      0.443     -5.157      0.000      -3.158      -1.416
# ...

# %%
model_tax=smf.ols(formula="crim~tax",data=Boston).fit()
print(model_tax.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     259.2
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           2.36e-47
# Time:                        07:49:04   Log-Likelihood:                -1701.4
# No. Observations:                 506   AIC:                             3407.
# Df Residuals:                     504   BIC:                             3415.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -8.5284      0.816    -10.454      0.000     -10.131      -6.926
# ...

# %%
model_ptratio=smf.ols(formula="crim~ptratio	",data=Boston).fit()
print(model_ptratio.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     46.26
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           2.94e-11
# Time:                        07:49:04   Log-Likelihood:                -1784.1
# No. Observations:                 506   AIC:                             3572.
# Df Residuals:                     504   BIC:                             3581.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -17.6469      3.147     -5.607      0.000     -23.830     -11.464
# ...

# %%
model_black=smf.ols(formula="crim~black",data=Boston).fit()
print(model_black.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.147
# Method:                 Least Squares   F-statistic:                     87.74
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           2.49e-19
# Time:                        07:49:04   Log-Likelihood:                -1765.8
# No. Observations:                 506   AIC:                             3536.
# Df Residuals:                     504   BIC:                             3544.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     16.5535      1.426     11.609      0.000      13.752      19.355
# ...

# %%
model_lstat=smf.ols(formula="crim~lstat",data=Boston).fit()
print(model_lstat.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     132.0
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           2.65e-27
# Time:                        07:49:04   Log-Likelihood:                -1747.5
# No. Observations:                 506   AIC:                             3499.
# Df Residuals:                     504   BIC:                             3507.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.3305      0.694     -4.801      0.000      -4.694      -1.968
# ...

# %%
model_medv=smf.ols(formula="crim~medv",data=Boston).fit()
print(model_medv.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     89.49
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           1.17e-19
# Time:                        07:49:04   Log-Likelihood:                -1765.0
# No. Observations:                 506   AIC:                             3534.
# Df Residuals:                     504   BIC:                             3542.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.7965      0.934     12.628      0.000       9.961      13.632
# ...

# %%
Boston['intercept']=1
model_all=sm.OLS(Boston['crim'],Boston[[ 'intercept','zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv']]).fit()
print(model_all.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     31.47
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):           1.57e-56
# Time:                        07:49:04   Log-Likelihood:                -1653.3
# No. Observations:                 506   AIC:                             3335.
# Df Residuals:                     492   BIC:                             3394.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     17.0332      7.235      2.354      0.019       2.818      31.248
# ...

# %% [markdown]
# #### We can reject the null hypotesis for [ 'zn',  'dis', 'rad', 'black',  'medv']

# %%
single_coefficients=[]
for model in [model_zn,model_indus,model_chas,model_nox,model_rm,model_age,model_dis,model_rad,model_tax,model_ptratio,model_black,model_lstat,model_medv]:
    single_coefficients.append(model.params[1]) 
multi_coefficients=list(model_all.params[1:])

# %%
print(single_coefficients)
print(multi_coefficients)
# Out:
# [-0.07393497740412372, 0.509776331104231, -1.8927765508037595, 31.24853120112293, -2.6840512241139485, 0.10778622713953305, -1.5509016824100994, 0.6179109273272023, 0.029742252822765342, 1.151982787070587, -0.036279640567330726, 0.548804782062398, -0.3631599222576031]
# [0.044855214670034116, -0.06385482358770489, -0.7491336105106051, -10.313534912066496, 0.43013050586404555, 0.0014516434361822096, -0.9871757255028896, 0.588208591473493, -0.0037800163848591235, -0.2710805584722495, -0.007537504888492068, 0.12621137645950195, -0.19888682126561685]

# %%
plt.scatter(x=single_coefficients,y=multi_coefficients,c='red',marker='o')

# %% [markdown]
# ##### There is a difference between the simple and multiple regression coefficients. This difference is due to the fact that in the simple regression case, the slope term represents the average effect of an increase in the predictor, ignoring other predictors. In contrast, in the multiple regression case, the slope term represents the average effect of an increase in the predictor, while holding other predictors fixed. It does make sense for the multiple regression to suggest no relationship between the response and some of the predictors while the simple linear regression implies the opposite because the correlation between the predictors show some strong relationships between some of the predictors.

# %%
sns.pairplot(data=Boston.drop('intercept',axis=1))
